# %%
using local_POD_overlap.module_2D

using LinearAlgebra
using Plots
using LaTeXStrings
using ProgressBars

import LinearAlgebra.eigvals 
using Statistics
using Random
using Distributions
using SparseArrays
import CairoMakie as cm

# %%
function overlap_shifter(data,overlap_MP;index = 3,forward = true)


    shift_x, shift_y = Int.(round.(1/2 .* overlap_MP.J))

    if forward
        shifted_x = circshift( data,(shift_x,0))
        shifted_y = circshift( data,(0,shift_y))
        shifted_x_y = circshift( data,(shift_x,shift_y))
    else
        shifted_x = circshift( data,(-shift_x,0))
        shifted_y = circshift( data,(0,-shift_y))
        shifted_x_y = circshift( data,(-shift_x,-shift_y))


    end
    
    indexes = collect(1:size(data)[index])
    shifted_indexes_x = indexes .+ size(data)[index]
    shifted_indexes_y = indexes .+ 2*size(data)[index]
    shifted_indexes_x_y = indexes .+ 3*size(data)[index]

    indexes = cat(indexes,shifted_indexes_x,shifted_indexes_y,shifted_indexes_x_y,dims = 2)'[1:end]
    
    modes = cat(data,shifted_x,shifted_y,shifted_x_y,dims = index)
    
    return modes[[(:) for i in 1:index-1]...,indexes,[(:) for i in 1:(length(size(modes))-index)]...]
end

function carry_out_local_SVD_overlap_2D_periodic_only(input,MP)

    UPC = MP.fine_mesh.UPC
    dims = MP.fine_mesh.dims
    
    overlap_fine_mesh = MP.fine_mesh
    overlap_coarse_mesh = gen_coarse_from_fine_mesh(fine_mesh, 2 .* MP.J)
    overlap_MP = gen_mesh_pair(overlap_fine_mesh,overlap_coarse_mesh)
    
    kernel_x= collect(LinRange(-1,1,overlap_MP.J[1]+1))
    kernel_y = collect(LinRange(-1,1,overlap_MP.J[2]+1))

    kernel_mesh = gen_mesh(kernel_x,kernel_y,UPC = UPC,use_GPU = false)
    kernel = kernel_mesh.eval_function(mollifier_bump_kernel)

    input =  overlap_shifter(input,overlap_MP,index = 4)
    reshaped_input = kernel .* reshape_for_local_SVD(input,overlap_MP,subtract_average = false)
    

    vector_input = reshape(reshaped_input,(prod(size(reshaped_input)[1:end-1]),size(reshaped_input)[end]))

    SVD = svd(vector_input)

    return  reshape(SVD.U,(overlap_MP.J...,UPC,Int(size(SVD.U)[end]))),SVD.S,overlap_MP
end




    


function bilinear_kernel(x)

    m1 = (x[1] .< 0) .* (x[2] .< 0)
    
    m2 = (x[1] .>= 0) .* (x[2] .< 0)
    m3 = (x[1] .< 0) .* (x[2] .>= 0) 
    m4 = (x[1] .>= 0) .* (x[2] .>= 0)

    
    x1,y1 = x[1] .+ 1, x[2] .+ 1
    x2,y2 = x[1] , x[2] .+ 1
    x3,y3 = x[1] .+ 1, x[2] 
    x4,y4 = x[1] , x[2] 

    

    

    

    f1 = (x1 ) .* (y1)
    f2 = (1 .- x2 ) .* ( y2 )
    f3 = (x3 ) .* (1 .- y3  )
    f4 = (1 .- x4) .* (1 .- y4)


    return m1 .* f1 .+ m2 .* f2 .+ m3 .* f3 .+ m4 .* f4
    #return m3
end


function mollifier_bump_kernel(x)

    m1 = (x[1] .< 0) .* (x[2] .< 0)
    
    m2 = (x[1] .>= 0) .* (x[2] .< 0)
    m3 = (x[1] .< 0) .* (x[2] .>= 0) 
    m4 = (x[1] .>= 0) .* (x[2] .>= 0)


    x1,y1 = x[1] .+ 1, x[2] .+ 1
    x2,y2 = x[1] , x[2] .+ 1
    x3,y3 = x[1] .+ 1, x[2] 
    x4,y4 = x[1] , x[2] 

    delta = 1e-10
    ## circumvent the NaN at x = 0
    x1,y1 = max.(x1,delta), max.(y1,delta)
    x2,y2 = max.(x2,delta), max.(y2,delta)
    x3,y3 = max.(x3,delta), max.(y3,delta)
    x4,y4 = max.(x4,delta), max.(y4,delta)

    
    eta(x) = exp.(-(x)/(x*(1-x)))

    eta_tilde(x) = eta(x)/(eta(x)+eta(1-x))
    a(x) = eta_tilde(x)
    b(x) = 1 -a(x)
    
    f1 = b.(x1) .* b.(y1)
    f2 = a.(x2) .* b.(y2)
    f3 = b.(x3) .* a.(y3)
    f4 = a.(x4) .* a.(y4)


    return m1 .* f1 .+ m2 .* f2 .+ m3 .* f3 .+ m4 .* f4
    #return m3
end




struct overlap_projection_operators_struct
    Phi_T
    Phi
    S_inv
    S
    inv_S
end

function generate_ROM_operator(input_dimension,proj_FOM_rhs)

    dummy_vec = zeros(input_dimension)

    
    
    ROM_operator = zeros((input_dimension...,input_dimension...))

    for i in 1:input_dimension[1]
        test_vec = copy(dummy_vec)
        test_vec[i] += 1

        
        result = proj_FOM_rhs(test_vec)
        #output = reshape(,shape_2)

        ROM_operator[:,i] .+= result

    end
    
    return ROM_operator
end

function sparsify_matrix(A,tolerance = 1e-16)
    B = spzeros(size(A))
    for i in 1:size(A)[1]
        for j in 1:size(A)[2]
            if abs(A[i,j]) >= tolerance
                B[i,j] += A[i,j]
            end
        end
    end
    return B
end

function generate_S(overlap_MP,Phi_T,Phi)

    dummy_input = zeros(overlap_MP.fine_mesh.N...,1,1)
    dummy_vec = 0 * Phi_T(dummy_input)

    shape_1 = size(dummy_vec)
    shape_2 = (prod(shape_1),)

    dummy_vec = reshape(dummy_vec,shape_2)
    
    
    S = zeros((shape_2[1],shape_2[1]))

    for i in 1:shape_2[1]
        test_vec = copy(dummy_vec)
        test_vec[i] += 1

        test_vec = reshape(test_vec,shape_1)

        corresponding_state = Phi(test_vec)
        corresponding_coefficients = Phi_T(corresponding_state)
        overlap = reshape(corresponding_coefficients,shape_2)
        
        #output = reshape(,shape_2)

        S[:,i] .+= overlap

    end
    
    return S
end


function generate_S_2(overlap_MP,Phi_T,Phi)

    dummy_input = zeros(overlap_MP.fine_mesh.N...,1,1)
    dummy_vec = 0 * Phi_T(dummy_input)

    shape_1 = size(dummy_vec)
    q = shape_1[3]
    shape_2 = (prod(shape_1),)

    #dummy_vec = reshape(dummy_vec,shape_2)
    
    
    S = zeros((shape_2[1],shape_2[1]))

    inner_products = zeros((shape_2[1],q))
    
    for i in 1:q
        test_vec = copy(dummy_vec)
        test_vec[1,1,i,1] = 1
        corresponding_state = Phi(test_vec)
        corresponding_coefficients = Phi_T(corresponding_state)
        coefficients = reshape(corresponding_coefficients,shape_2)
        inner_products[:,i] = coefficients
    end

    counter = 1
    for i in 1:q
        coefficients = reshape(inner_products[:,i],shape_1)
        for y in 0:shape_1[2]-1
            for x in 0:shape_1[1]-1
                shifted_coeffs = circshift(coefficients,(x,y,0,0))
                S[:,counter] = reshape(shifted_coeffs,shape_2)
                counter += 1
            end
        end
    end

    
    

    
    return S#rand(Normal(0,1),size(S))
end





function gen_projection_operators_overlap_2D_periodic_only(overlap_modes,overlap_MP)
    PO = gen_projection_operators(overlap_modes,overlap_MP)
    
    function Phi_T(input,PO = PO,overlap_MP = overlap_MP)
        


        dims = overlap_MP.fine_mesh.dims
        shift_x, shift_y = Int.(round.(1/2 .* overlap_MP.J))

        output_1 = PO.Phi_T(input)
        output_2 = PO.Phi_T(circshift(input,(shift_x,0)))
        output_3 = PO.Phi_T(circshift(input,(0,shift_y)))
        output_4 = PO.Phi_T(circshift(input,(shift_x,shift_y)))

        indexes = collect(1:size(output_1)[dims+1])
        shifted_indexes_x = indexes .+ size(output_1)[dims+1]
        shifted_indexes_y = indexes .+ 2*size(output_1)[dims+1]
        shifted_indexes_x_y = indexes .+ 3*size(output_1)[dims+1]
    
        indexes = cat(indexes,shifted_indexes_x,shifted_indexes_y,shifted_indexes_x_y,dims = 2)'[1:end]
    
        
        output = cat(output_1,output_2,output_3,output_4,dims = dims + 1)

        return output[:,:,indexes,:]
        return input
    end

    function Phi(input,PO = PO,overlap_MP = overlap_MP)

        dims = overlap_MP.fine_mesh.dims
        
        shift_x, shift_y = Int.(round.(1/2 .* overlap_MP.J))
        
        number_of_modes = size(input)[dims+1]
        unique_modes = Int(round(number_of_modes/4))
        index_1 = 4 * collect(0:unique_modes-1) .+ 1 
        index_2 = index_1 .+ 1
        index_3 = index_1 .+ 2
        index_4 = index_1 .+ 3


        output_1 = PO.Phi(input[:,:,index_1,:]) 
        output_2 = circshift(PO.Phi(input[:,:,index_2,:]),(-shift_x,0) )
        output_3 = circshift(PO.Phi(input[:,:,index_3,:]),(0,-shift_y)) 
        output_4 = circshift(PO.Phi(input[:,:,index_4,:]),(-shift_x,-shift_y)) 
        
       
        return output_1 .+ output_2 .+ output_3 .+ output_4
    end

    S = generate_S_2(overlap_MP,Phi_T,Phi)
    inv_S = inv(Matrix(S))
    
    function S_inv(input,S = S, inv_S = inv_S)

        shape_1 = size(input)
        shape_2 = (prod(shape_1[1:end-1]),shape_1[end])

        reshaped_input = reshape(input,shape_2)
        solved = inv_S * reshaped_input
        #solved = solve(S,reshaped_input)
        output = reshape(solved,shape_1)
        
        
        return output


    end 

    
    return overlap_projection_operators_struct(Phi_T,Phi,S_inv,S,inv_S)
end


function proj_FOM(a,PO,rhs,fine_mesh)
    new_shape = size(PO.Phi_T(fine_mesh.omega))
    num_inputs = Int(round(prod(size(a))/prod(new_shape)))
    
    old_shape = prod(size(a))
    new_shape = (new_shape[1:end-1]...,num_inputs)

    c_r = PO.Phi(reshape(a,new_shape))
    rhs_c = rhs(c_r,fine_mesh,0)
    rhs_a = PO.Phi_T(rhs_c)
    

    
    rhs_a = reshape(rhs_a,old_shape)
    return rhs_a
end
# Out:
# proj_FOM (generic function with 1 method)

# %%
N = (256,256)
UPC = 1       
use_GPU = false

x= collect(LinRange(-pi,pi,N[1]+1))
y = collect(LinRange(-pi,pi,N[2]+1))

fine_mesh = gen_mesh(x,y,UPC = UPC,use_GPU = use_GPU)
velocity_mesh = gen_mesh(x,y,UPC = fine_mesh.dims,use_GPU = use_GPU)
setup = gen_setup(velocity_mesh)
0
# Out:
# ┌ Warning: Layer with Float32 parameters got Float64 input.
# │   The input will be converted, but any earlier layers may be very slow.
# │   layer = Conv((3, 3), 2 => 2, bias=false)  # 36 parameters
# │   summary(x) = "258×258×2×1 Array{Float64, 4}"
# └ @ Flux ~/.julia/packages/Flux/3711C/src/layers/stateless.jl:60
# 0

# %%
u_f(x) =  cos.(x[1] - x[2]) #.* sin.(x[1])
v_f(x) =  cos.(x[1] - x[2]) #sin.(x[2]) .* sin.(x[1])


u = velocity_mesh.eval_function(u_f)
v = velocity_mesh.eval_function(v_f)

V1 = cat(u,v,dims = 3)[:,:,:,:]
#V =  d["Vbar"][:,:,:,1:1,1] # .+ 1
w_1 = setup.O.w(V1)
V = project_divergence(V1,setup)
w_2 = setup.O.w(V)
setup.O.M(V)
0
# Out:
# 0

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title = L"u = v = \cos(x-y)",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],V[:,:,1,1])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/V.pdf", fig)
fig

# %%
c0_f_1(x) = exp.(-2*((x[1] .- 1/2*pi ).^2 .+ (x[2] .+ 1/2*pi ).^2))

c0_f_2(x) = exp.(-2*((x[1] .+ 1/2*pi).^2 .+ (x[2].- 1/2*pi).^2))

c0_f_3(x) = -exp.(-2*((x[1] ).^2 .+ (x[2]).^2))


c0_f(x) = c0_f_1(x) + c0_f_2(x) + c0_f_3(x) 

c0 = fine_mesh.eval_function(c0_f)
0
# Out:
# 256×256×1×1 Array{Float64, 4}:
# [:, :, 1, 1] =
#  -9.73603e-18  -1.32215e-17  -1.79116e-17  …   7.0198e-5     6.03111e-5
#  -1.32215e-17  -1.79549e-17  -2.43241e-17      8.17056e-5    7.0198e-5
#  -1.79116e-17  -2.43241e-17  -3.29528e-17      9.48708e-5    8.15089e-5
#  -2.4207e-17   -3.28733e-17  -4.45348e-17      0.000109892   9.44147e-5
#  -3.26361e-17  -4.43203e-17  -6.00426e-17      0.000126986   0.000109101
#  -4.38942e-17  -5.96092e-17  -8.07555e-17  …   0.000146385   0.000125768
#  -5.88938e-17  -7.99792e-17  -1.08352e-16      0.000168341   0.000144632
#  -7.88285e-17  -1.07051e-16  -1.45029e-16      0.000193125   0.000165925
#  -1.05257e-16  -1.42942e-16  -1.93652e-16      0.000221025   0.000189895
#  -1.40206e-16  -1.90405e-16  -2.57955e-16      0.000252346   0.000216805
#  -1.86309e-16  -2.53017e-16  -3.42781e-16  …   0.000287413   0.000246933
#  -2.46976e-16  -3.35407e-16  -4.54402e-16      0.000326564   0.00028057
# ...

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title = L"c(\mathbf{x},0)",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],c0[:,:,1,1])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/c0.pdf", fig)
fig

# %%
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:46
#  48.564589 seconds (12.62 M allocations: 111.172 GiB, 16.17% gc time, 28.59% compilation time)
# 256×256×1×100 Array{Float64, 4}:
# [:, :, 1, 1] =
#  -3.12071e-5  -1.53295e-5   7.50354e-6  …  -6.89128e-6  -1.64038e-5
#  -1.53295e-5  -5.06396e-6   1.40635e-5      1.27262e-5   1.6714e-6
#   7.50353e-6   1.40635e-5   2.97875e-5      3.43506e-5   2.43088e-5
#  -2.87126e-6   5.13696e-6   2.15934e-5      1.30455e-5   8.82085e-6
#  -3.1411e-5   -2.18986e-5  -4.05967e-6     -2.28827e-5  -2.35824e-5
#  -3.13891e-5  -2.55442e-5  -1.07262e-5  …  -1.72371e-5  -2.13377e-5
#   4.89794e-6   4.6279e-6    1.33327e-5      2.84107e-5   1.92165e-5
#   3.54535e-5   3.3484e-5    3.89189e-5      5.69182e-5   4.87947e-5
#   2.15963e-5   2.46115e-5   3.2644e-5       2.76004e-5   2.73702e-5
#  -2.97922e-5  -1.97443e-5  -6.35402e-6     -4.01743e-5  -3.24509e-5
#  -7.62088e-5  -6.36577e-5  -4.79159e-5  …  -9.01266e-5  -8.14509e-5
# ...

# %%
viscosity = 0.001
rhs = gen_rhs_advection_equation(setup,V = V,viscosity = viscosity,F = 0*c0)
t,  to_plot_res = simulate(c0,fine_mesh,0.025,0,12,rhs,save_every = 2,pre_allocate = true)
to_plot_res = to_plot_res[:,:,:,1,:]
0
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:09
#   9.465663 seconds (756.65 k allocations: 33.410 GiB, 18.70% gc time)
# 256×256×1×240 Array{Float64, 4}:
# [:, :, 1, 1] =
#  -1.20599e-5   2.55148e-5   5.88751e-5   …   3.88651e-6   -2.49069e-5
#   2.55148e-5   2.69187e-5   3.43724e-5       4.20644e-5    3.29569e-5
#   5.88751e-5   3.43724e-5   2.12052e-5       7.36183e-5    7.75731e-5
#   8.18112e-5   4.16854e-5   1.73297e-5       9.55307e-5    0.000106961
#   9.87418e-5   4.8508e-5    1.76497e-5       0.000113858   0.000129355
#   0.000115025  5.59489e-5   1.97225e-5   …   0.000132524   0.000151066
#   0.000132815  6.43632e-5   2.25493e-5       0.000153279   0.00017487
#   0.000152809  7.38508e-5   2.5807e-5        0.000176757   0.00020173
#   0.000175318  8.44686e-5   2.94362e-5       0.000203325   0.000232136
#   0.000200576  9.62899e-5   3.34451e-5       0.000233321   0.000266489
#   0.000228822  0.000109394  3.78492e-5   …   0.000267094   0.000305194
# ...

# %%
to_plot = to_plot_res[:,:,1,:]
#to_plot = setup_bar.O.w(pred_sim[:,:,1:2,:])[:,:,1,:]

ymin = minimum(to_plot)
ymax = maximum(to_plot)

fig = cm.Figure(size = (350, 300))
ax = cm.Axis(fig[1, 1],titlesize = 20,xticklabelsize = 10,yticklabelsize = 10)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],to_plot[:,:,1])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 10)



cm.record(fig, "plots_2D/DNS_flow.gif", 1:size(to_plot)[3],framerate = 30) do i
    hm[3] = to_plot[:,:,i] # update data
    cm.Colorbar(fig[1, 2], hm,ticklabelsize = 10)
    # yield() -> not required with record
end
# Out:
# "plots_2D/DNS_flow.gif"

# %%
viscosity = 0.001
rhs = gen_rhs_advection_equation(setup,V = V,viscosity = viscosity,F = 0*c0)
t,  res = simulate(c0,fine_mesh,0.025,0,40,rhs,save_every = 16,pre_allocate = true)
res = res[:,:,:,1,:]
0
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:34
#  34.100645 seconds (2.40 M allocations: 110.679 GiB, 21.27% gc time)
# 0

# %%
training_data = res[:,:,:,1:30]
validation_data = res[:,:,:,41:50]
test_data = res[:,:,:,51:100]
# Out:
# 256×256×1×50 Array{Float64, 4}:
# [:, :, 1, 1] =
#   3.42801e-5    3.47346e-5    3.1008e-5    …   2.552e-5      3.14382e-5
#   3.47324e-5    3.74034e-5    3.73833e-5       1.57574e-5    2.86366e-5
#   3.10068e-5    3.73833e-5    3.99688e-5      -1.06587e-5    1.73083e-5
#   1.81598e-5    3.27915e-5    3.95388e-5      -6.87116e-5   -1.16317e-5
#  -1.33059e-5    1.84543e-5    3.4126e-5       -0.000182641  -7.38157e-5
#  -7.9734e-5    -1.55877e-5    1.82898e-5   …  -0.000389689  -0.000194502
#  -0.000207408  -8.63974e-5   -1.84006e-5      -0.000744216  -0.000412315
#  -0.000436405  -0.000221336  -9.37625e-5      -0.00132175   -0.000783465
#  -0.000824813  -0.000461967  -0.000236271     -0.00222193   -0.00138572
#  -0.0014527    -0.000868312  -0.000489023     -0.00356934   -0.00232127
#  -0.00242482   -0.00152277   -0.000914019  …  -0.00551069   -0.00371729
#  -0.00387098   -0.00253272   -0.00159605      -0.00820751   -0.00572283
# ...

# %% [markdown]
# # Convergence test

# %%
function compute_L2(a_pred,a_ref;average = true)
    if average
        return mean(sqrt.(sum((a_pred-a_ref).^2,dims = [1,2])) ./ sqrt.(sum((a_ref).^2,dims = [1,2])))
    else
        return sqrt.(sum((a_pred-a_ref).^2,dims = [1,2])) ./ sqrt.(sum((a_ref).^2,dims = [1,2]))
    end
end
# Out:
# compute_L2 (generic function with 1 method)

# %%
r_max = 2000
#Is = [1,8,16,32]
#Is = [8,16,32]
#Is = [1]
Is = [1,2,4,8,16]
local_errors_training = Dict()
overlap_errors_training = Dict()

local_errors_validation = Dict()
overlap_errors_validation = Dict()

for I in Is

    J = Int.(round.((1/I) .* fine_mesh.N)) # compression in each direction

    coarse_mesh = gen_coarse_from_fine_mesh(fine_mesh,J)
    MP = gen_mesh_pair(fine_mesh,coarse_mesh)


    local_errors_training[(I,J[1])] = []
    overlap_errors_training[(I,J[1])] = []

    local_errors_validation[(I,J[1])] = []
    overlap_errors_validation[(I,J[1])] = []

    
    modes,S = carry_out_local_SVD(training_data,MP)

    if I > 1
        overlap_modes,overlap_S,overlap_MP = carry_out_local_SVD_overlap_2D_periodic_only(training_data,MP)
    end

    qs = collect(Int.(collect(1:1:minimum([I^2 * size(training_data)[end],r_max/(I^2)]))))
    #print(qs)
    for q in qs
        
        local_PO = gen_projection_operators(modes[:,:,:,1:q],MP)
        
        local_a = local_PO.Phi_T(training_data)
        local_c_r = local_PO.Phi(local_a)
    
        local_error = compute_L2(local_c_r,training_data)
        

        push!(local_errors_training[(I,J[1])],local_error)


        local_a = local_PO.Phi_T(validation_data)
        local_c_r = local_PO.Phi(local_a)

        local_error = compute_L2(local_c_r,validation_data)

        push!(local_errors_validation[(I,J[1])],local_error)
        
        

        ## Compute overlap error
        if I > 1
            overlap_PO = gen_projection_operators_overlap_2D_periodic_only(overlap_modes[:,:,:,1:q],overlap_MP)
            overlap_a = overlap_PO.Phi_T(training_data)
            solved = overlap_PO.S_inv(overlap_a)
            overlap_c_r = overlap_PO.Phi(solved)
    
            overlap_error = compute_L2(overlap_c_r,training_data)
    
            push!(overlap_errors_training[(I,J[1])],overlap_error)
                
            overlap_a = overlap_PO.Phi_T(validation_data)
            solved = overlap_PO.S_inv(overlap_a)
            overlap_c_r = overlap_PO.Phi(solved)
        
            
            overlap_error = compute_L2(overlap_c_r,validation_data)
            
            
            push!(overlap_errors_validation[(I,J[1])],overlap_error)
        end
    end
end

# %%
all_keys = keys(local_errors_training)
Is = sort([i[1] for i in all_keys])
Js = reverse(sort([i[2] for i in all_keys]))
rs = collect(1:size(overlap_errors_training[(Is[1],Js[1])])[1])
plot(yscale = :log10,xscale = :log10,xtickfont=font(13), 
    ytickfont=font(11), 
    guidefont=font(17), 
    legendfont=font(13),legend= :bottomleft)
#plot()
for i in 1:size(Is)[1]
    I = Is[i]
    J = Js[i]
    qs = collect(1:size(local_errors_training[(I,J)])[1])
    plot!(I^2 .* qs,local_errors_training[(Is[i],Js[i])],color = i,label = L"I = %$I \times %$I",linewidth = 2, marker = true)
    if i != 1
        plot!(I^2 .* qs,overlap_errors_training[(Is[i],Js[i])],color = i,label = false,linestyle = :dash,linewidth = 2, marker = :star)
    end
end
hline!([0.01],label = false,linewidth = 2,color = :black)
xlabel!(L"r")
ylabel!(L"||" *"Projection error"* L"||_2/||\mathbf{c}||_2")
title!("Training")
savefig("plots_2D/training_error.pdf")
plot!()

# %%
all_keys = keys(local_errors_training)
Is = sort([i[1] for i in all_keys])
Js = reverse(sort([i[2] for i in all_keys]))
rs = collect(1:size(overlap_errors_training[(Is[1],Js[1])])[1])
plot(yscale = :log10,xscale = :log10,xtickfont=font(13), 
    ytickfont=font(11), 
    guidefont=font(17), 
    legendfont=font(13),legend= :bottomleft)
#plot()
for i in 1:size(Is)[1]
    I = Is[i]
    J = Js[i]
    qs = collect(1:size(local_errors_training[(I,J)])[1])
    plot!(I^2 .* qs,local_errors_validation[(Is[i],Js[i])],color = i,label = L"I = %$I \times %$I",linewidth = 2, marker = true)
    if i != 1
        plot!(I^2 .* qs,overlap_errors_validation[(Is[i],Js[i])],color = i,label = false,linestyle = :dash,linewidth = 2, marker = :star)
    end
end
hline!([10^(-2)],label = false,linewidth = 2,color = :black)
xlabel!(L"r")
ylabel!(L"||" *"Projection error"* L"||_2/||\mathbf{c}||_2")
title!("Validation")
savefig("plots_2D/validation_error.pdf")
plot!()

# %% [markdown]
# # Convergence study

# %%
FD_convergence_errors = []
FD_res = 0
dt = 0.025

convergence_resolutions = collect(10:10:256) 

for r in convergence_resolutions
    

    
    N = (r,r)
    UPC = 1       
    use_GPU = false
    
    x= collect(LinRange(-pi,pi,N[1]+1))
    y = collect(LinRange(-pi,pi,N[2]+1))
    
    FD_mesh = gen_mesh(x,y,UPC = UPC,use_GPU = use_GPU)
    FD_velocity_mesh = gen_mesh(x,y,UPC = FD_mesh.dims,use_GPU = use_GPU)
    
    
    FD_setup = gen_setup(FD_velocity_mesh)


    FD_u = FD_velocity_mesh.eval_function(u_f)
    FD_v = FD_velocity_mesh.eval_function(v_f)

    FD_V = cat(FD_u,FD_v,dims = 3)[:,:,:,:]
    FD_V = project_divergence(FD_V,FD_setup)

    FD_c0 = FD_mesh.eval_function(c0_f)
    
    
   
    FD_rhs = gen_rhs_advection_equation(FD_setup,V = FD_V,viscosity = viscosity)

    t,  FD_res = simulate(FD_c0,FD_mesh,dt,0,40,FD_rhs,save_every = 16,pre_allocate = true)
    error = compute_L2(linear_interpolation_2D(FD_res[:,:,:,1,:],FD_mesh,fine_mesh),res[:,:,:,:])
    push!(FD_convergence_errors,error)

end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:02
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:04
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:05
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:06
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:07
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:08
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:09
# ...

# %%
plot(convergence_resolutions,FD_convergence_errors,marker = true, linewidth = 2)

# %% [markdown]
# # Experiment with the timestep

# %%
resolutions = [16,32,64,128]
dt_factors = [1,2,4,8]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  4
#  8

# %%
FD_errors = Dict()
FD_res = 0
dt = 0.025


for r in resolutions
    
    FD_errors[r] = []
    for factor in dt_factors
        new_dt = dt * factor
        N = (r,r)
        UPC = 1       
        use_GPU = false
        
        x= collect(LinRange(-pi,pi,N[1]+1))
        y = collect(LinRange(-pi,pi,N[2]+1))
        
        FD_mesh = gen_mesh(x,y,UPC = UPC,use_GPU = use_GPU)
        FD_velocity_mesh = gen_mesh(x,y,UPC = FD_mesh.dims,use_GPU = use_GPU)
        
        
        FD_setup = gen_setup(FD_velocity_mesh)
    
    
        FD_u = FD_velocity_mesh.eval_function(u_f)
        FD_v = FD_velocity_mesh.eval_function(v_f)

        FD_V = cat(FD_u,FD_v,dims = 3)[:,:,:,:]
        FD_V = project_divergence(FD_V,FD_setup)

        FD_c0 = FD_mesh.eval_function(c0_f)
        
        
       
        FD_rhs = gen_rhs_advection_equation(FD_setup,V = FD_V,viscosity = viscosity)
    
        t,  FD_res = simulate(FD_c0,FD_mesh,new_dt,0,40,FD_rhs,save_every = Int(round(16/factor)),pre_allocate = true)
        FD_res = FD_res[:,:,:,1,:]
        error = compute_L2(linear_interpolation_2D(FD_res[:,:,:,50:100],FD_mesh,fine_mesh),res[:,:,:,50:100])
    
        push!(FD_errors[r],error)
    end
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:02
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:11
# ...

# %% [markdown]
# # Implicit solver

# %%
I = (8,8)
J = Int.(round.(fine_mesh.N ./I))
# compression in each direction
coarse_mesh = gen_coarse_from_fine_mesh(fine_mesh,J)
local_MP = gen_mesh_pair(fine_mesh,coarse_mesh)


local_modes,local_S = carry_out_local_SVD(training_data,local_MP)
overlap_modes,overlap_S,overlap_MP = carry_out_local_SVD_overlap_2D_periodic_only(training_data,local_MP)


I = (1,1)
J = Int.(round.(fine_mesh.N ./I))
# compression in each direction
coarse_mesh = gen_coarse_from_fine_mesh(fine_mesh,J)
global_MP = gen_mesh_pair(fine_mesh,coarse_mesh)
global_modes,global_S = carry_out_local_SVD(training_data,global_MP)
0
# Out:
# 0

# %%
# Create a figure
fig = cm.Figure(size = (1500, 400))

# First surface plot
ax1 = cm.Axis3(fig[1, 1], title = L"\gamma_{11}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax1,fine_mesh.x[1:size(local_modes)[1],1,1,1] , fine_mesh.x[1:size(local_modes)[1],1,1,1], local_modes[:,:,1,1])

# Second surface plot
ax2 = cm.Axis3(fig[1, 2], title = L"\gamma_{12}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax2,fine_mesh.x[1:size(local_modes)[1],1,1,1] , fine_mesh.x[1:size(local_modes)[1],1,1,1], local_modes[:,:,1,2])

# Third surface plot
ax3 = cm.Axis3(fig[1, 3], title = L"\gamma_{13}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax3,fine_mesh.x[1:size(local_modes)[1],1,1,1] , fine_mesh.x[1:size(local_modes)[1],1,1,1], local_modes[:,:,1,3])

# Save or display the figure
cm.save("plots_2D/local_modes.png", fig)
fig

# %%
# Create a figure
fig = cm.Figure(size = (1500, 400))

# First surface plot
ax1 = cm.Axis3(fig[1, 1], title = L"\gamma_{11}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax1,fine_mesh.x[1:size(overlap_modes)[1],1,1,1] , fine_mesh.x[1:size(overlap_modes)[1],1,1,1], overlap_modes[:,:,1,1])

# Second surface plot
ax2 = cm.Axis3(fig[1, 2], title = L"\gamma_{12}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax2,fine_mesh.x[1:size(overlap_modes)[1],1,1,1] , fine_mesh.x[1:size(overlap_modes)[1],1,1,1], overlap_modes[:,:,1,2])

# Third surface plot
ax3 = cm.Axis3(fig[1, 3], title = L"\gamma_{13}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax3,fine_mesh.x[1:size(overlap_modes)[1],1,1,1] , fine_mesh.x[1:size(overlap_modes)[1],1,1,1], overlap_modes[:,:,1,3])

# Save or display the figure
cm.save("plots_2D/overlap_modes.png", fig)
fig

# %%
# Create a figure
fig = cm.Figure(size = (1500, 400))

# First surface plot
ax1 = cm.Axis3(fig[1, 1], title = L"\phi_{1}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax1,fine_mesh.x[1:size(global_modes)[1],1,1,1] , fine_mesh.x[1:size(global_modes)[1],1,1,1], global_modes[:,:,1,1])

# Second surface plot
ax2 = cm.Axis3(fig[1, 2], title = L"\phi_{2}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax2,fine_mesh.x[1:size(global_modes)[1],1,1,1] , fine_mesh.x[1:size(global_modes)[1],1,1,1], global_modes[:,:,1,2])

# Third surface plot
ax3 = cm.Axis3(fig[1, 3], title = L"\phi_{3}",zlabel = "",titlesize = 40,xlabelsize = 25,ylabelsize = 25,xticklabelsize = 15,yticklabelsize = 15,zticklabelsize = 15)
cm.surface!(ax3,fine_mesh.x[1:size(global_modes)[1],1,1,1] , fine_mesh.x[1:size(global_modes)[1],1,1,1], global_modes[:,:,1,3])

# Save or display the figure
cm.save("plots_2D/global_modes.png", fig)
fig

# %%
q_local = 20
q_overlap = 15
q_global = size(global_modes)[end]

local_PO = gen_projection_operators(local_modes[:,:,:,1:q_local],local_MP)
overlap_PO = gen_projection_operators_overlap_2D_periodic_only(overlap_modes[:,:,:,1:q_overlap],overlap_MP)
global_PO = gen_projection_operators(global_modes,global_MP)
# Out:
# projection_operators_struct(Conv((256, 256), 1 => 30, stride=256, bias=false), ConvTranspose((256, 256), 30 => 1, stride=256, bias=false))

# %%
compute_L2(local_PO.Phi(local_PO.Phi_T(validation_data)), validation_data)
# Out:
# 0.009195880743543898

# %%
compute_L2(overlap_PO.Phi(overlap_PO.S_inv(overlap_PO.Phi_T(validation_data))), validation_data)
# Out:
# 0.008803094870020432

# %%
local_proj_FOM(a,PO = local_PO,rhs = rhs,fine_mesh = fine_mesh) = proj_FOM(a,PO,rhs,fine_mesh)
overlap_proj_FOM(a,PO = overlap_PO,rhs = rhs,fine_mesh = fine_mesh) = proj_FOM(a,PO,rhs,fine_mesh)
global_proj_FOM(a,PO = global_PO,rhs = rhs,fine_mesh = fine_mesh) = proj_FOM(a,PO,rhs,fine_mesh)
0
# Out:
# 0

# %%
c0 = fine_mesh.eval_function(c0_f)
local_a0 = local_PO.Phi_T(c0)[1:end]
overlap_a0 = overlap_PO.S_inv(overlap_PO.Phi_T(c0))[1:end]
global_a0 = global_PO.Phi_T(c0)[1:end]

local_A = sparsify_matrix(Matrix(generate_ROM_operator(size(local_a0),local_proj_FOM)))
overlap_A =  sparsify_matrix(generate_ROM_operator(size(overlap_a0),overlap_proj_FOM))
global_A =  sparsify_matrix(generate_ROM_operator(size(global_a0),global_proj_FOM))
0

sp_S = sparsify_matrix(overlap_PO.S)
# Out:
# 960×960 SparseMatrixCSC{Float64, Int64} with 129600 stored entries:
# ⎡⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎤
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎢⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎥
# ⎣⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⎦

# %%
local_rhs(a,mesh,t;A = local_A,other_arguments = 0) = A * a
global_rhs(a,mesh,t;A = global_A,other_arguments = 0) = A * a

overlap_rhs(a,mesh,t,A = overlap_A, S = lu(sp_S);other_arguments = 0) = S \ (A * a)
# Out:
# overlap_rhs (generic function with 3 methods)

# %%
local_errors = []
overlap_errors = []
global_errors = []
FD_res = 0
dt = 0.025

for factor in dt_factors

    new_dt = dt * factor



    B = (sp_S - new_dt/2 * overlap_A)
    C = (sp_S + new_dt/2 * overlap_A)
    
    B = lu(B)
    
    function overlap_CN_step(input,mesh,t,dt,rhs;B = B,C = C,other_arguments = 0)
        return B \ (C * input)
    end
    
    t,  local_res = simulate(local_a0,coarse_mesh,new_dt,0,40,local_rhs,save_every = Int(round(16/factor)),pre_allocate = true)
    t,  overlap_res = simulate(overlap_a0,coarse_mesh,new_dt,0,40,overlap_rhs,time_step_function = overlap_CN_step,save_every = Int(round(16/factor)),pre_allocate = true)
    t,  global_res = simulate(global_a0,global_MP.coarse_mesh,new_dt,0,40,global_rhs,save_every = Int(round(16/factor)),pre_allocate = true)
    
    

    local_res = local_PO.Phi(reshape(local_res,(local_MP.coarse_mesh.N...,q_local,size(local_res)[end])))
    overlap_res = overlap_PO.Phi(reshape(overlap_res,(overlap_MP.coarse_mesh.N...,4*q_overlap,size(overlap_res)[end])))
    global_res = global_PO.Phi(reshape(global_res,(global_MP.coarse_mesh.N...,q_global,size(global_res)[end])))


    
    local_error = compute_L2(local_res[:,:,:,:],res[:,:,:,:])
    push!(local_errors,local_error)


    overlap_error = compute_L2(overlap_res[:,:,:,:],res[:,:,:,:])
    push!(overlap_errors,overlap_error)
    
    global_error = compute_L2(global_res[:,:,:,:],res[:,:,:,:])
    push!(global_errors,global_error)
    

    
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00

# %%
plot(yscale = :log10,xscale = :log2,xtickfont=font(11), 
    ytickfont=font(11), 
    guidefont=font(17), 
    legendfont=font(13),legend= :right)
plot!(dt_factors,local_errors,marker = true,linewidth = 2, label = "L-POD")
plot!(dt_factors,overlap_errors,marker = true,linewidth = 2, label = "LO-POD")
plot!(dt_factors,global_errors,marker = true,linewidth = 2, label = "G-POD")
#plot!(dt_factors,FD_errors[16],marker = :star,linewidth = 2, label = "FD: " * L"16 \times 16")
#plot!(dt_factors,FD_errors[32],marker = :star,linewidth = 2, label = "FD: " * L"32 \times 32")
#plot!(dt_factors,FD_errors[64],marker = :star,linewidth = 2, label = "FD: " * L"64 \times 64")
plot!(dt_factors,FD_errors[128],marker = :star,linewidth = 2, label = "FD: " * L"128 \times 128")
ylabel!(L"||" *"Solution error"* L"||_2/||\mathbf{c}||_2")
xlabel!("Time step size increased by factor")
savefig("plots_2D/time_step_increased.pdf")
plot!()

# %%
dt = 0.025

save_every = 8

local_factor = 4
overlap_factor = 1
global_factor = 8
FD_factor = 2



repetitions = 6 #### Carry out the simulation for this many repetitions

sp_S = sparsify_matrix(overlap_PO.S)

B = (sp_S - (overlap_factor * dt)/2 * overlap_A)
C = (sp_S + (overlap_factor * dt)/2 * overlap_A)

B = lu(B)

function overlap_CN_step(input,mesh,t,dt,rhs;B = B,C = C,other_arguments = 0)
    return B \ (C * input)
end

eval_times = []
ref_res = 0
for i in 1:repetitions
    eval_time = @timed begin t,  ref_res = simulate(c0,fine_mesh,0.025,0,40,rhs,save_every = save_every,pre_allocate = true)
    end 
    push!(eval_times,eval_time[2])
end
ref_eval_time = mean(eval_times[2:end])

eval_times = []
local_res = 0
for i in 1:repetitions
    eval_time = @timed begin t,  local_res = simulate(local_a0,coarse_mesh,local_factor * dt,0,40,local_rhs,save_every = Int(round(save_every/local_factor)),pre_allocate = true)
    end 
    push!(eval_times,eval_time[2])
end
local_eval_time = mean(eval_times[2:end])

eval_times = []
overlap_res = 0
for i in 1:repetitions
    eval_time = @timed begin t,  overlap_res = simulate(overlap_a0,coarse_mesh,overlap_factor * dt,0,40,overlap_rhs,time_step_function = overlap_CN_step,save_every = Int(round(save_every/overlap_factor)),pre_allocate = true)
    end 
    push!(eval_times,eval_time[2])
end
overlap_eval_time = mean(eval_times[2:end])

eval_times = []
global_res = 0
for i in 1:repetitions
    eval_time = @timed begin t,  global_res = simulate(global_a0,global_MP.coarse_mesh,global_factor *dt,0,40,global_rhs,save_every = Int(round(save_every/global_factor)),pre_allocate = true)
    end 
    push!(eval_times,eval_time[2])
end
global_eval_time = mean(eval_times[2:end])


##### FD Simulation on 128 x 128 grid
FD_N = (128,128)
UPC = 1       
use_GPU = false

x= collect(LinRange(-pi,pi,FD_N[1]+1))
y = collect(LinRange(-pi,pi,FD_N[2]+1))

FD_mesh = gen_mesh(x,y,UPC = UPC,use_GPU = use_GPU)
FD_velocity_mesh = gen_mesh(x,y,UPC = FD_mesh.dims,use_GPU = use_GPU)


FD_setup = gen_setup(FD_velocity_mesh)


FD_u = FD_velocity_mesh.eval_function(u_f)
FD_v = FD_velocity_mesh.eval_function(v_f)

FD_V = cat(FD_u,FD_v,dims = 3)[:,:,:,:]
FD_V = project_divergence(FD_V,FD_setup)

FD_c0 = FD_mesh.eval_function(c0_f)



FD_rhs = gen_rhs_advection_equation(FD_setup,V = FD_V,viscosity = viscosity)

eval_times = []
FD_res = 0
t = 0
for i in 1:repetitions
    eval_time = @timed begin t,  FD_res = simulate(FD_c0,FD_mesh,FD_factor * dt,0,40,FD_rhs,save_every = Int(round(save_every/FD_factor)),pre_allocate = true)
    end 
    push!(eval_times,eval_time[2])
end
FD_eval_time = mean(eval_times[2:end])
t = t[1:end]

###############
ref_res = ref_res[:,:,:,1,:]
local_res = local_PO.Phi(reshape(local_res,(local_MP.coarse_mesh.N...,q_local,size(local_res)[end])))
overlap_res = overlap_PO.Phi(reshape(overlap_res,(overlap_MP.coarse_mesh.N...,4*q_overlap,size(overlap_res)[end])))
global_res = global_PO.Phi(reshape(global_res,(global_MP.coarse_mesh.N...,q_global,size(global_res)[end])))
FD_res = linear_interpolation_2D(FD_res[:,:,:,1,:],FD_mesh,fine_mesh)
###############
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:27
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:32
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:32
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:31
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:32
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:30
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# ...

# %%
print("Evaluation times: \n")
print("L-POD: ")
print(local_eval_time)
print("\nLO-POD: ")
print(overlap_eval_time)
print("\nG-POD: ")
print(global_eval_time)
print("\nFD: ")
print(FD_eval_time)
print("\nDNS: ")
print(ref_eval_time)
# Out:
# Evaluation times:
# L-POD: 0.2707865594
# LO-POD: 1.439794793
# G-POD: 0.0027007718
# FD: 5.7877855998
# DNS: 31.787026835999995

# %%
local_error = compute_L2(local_res,ref_res,average = false)[1:end]
overlap_error = compute_L2(overlap_res,ref_res,average = false)[1:end] 
global_error = compute_L2(global_res,ref_res,average = false)[1:end]
FD_error = compute_L2(FD_res,ref_res,average = false)[1:end]


local_energy = 1/2 *  fine_mesh.ip(local_res,local_res)[1:end]
overlap_energy = 1/2 *  fine_mesh.ip(overlap_res,overlap_res)[1:end] 
global_energy = 1/2 *  fine_mesh.ip(global_res,global_res)[1:end]
FD_energy = 1/2 *  fine_mesh.ip(FD_res,FD_res)[1:end]
ref_energy = 1/2 *  fine_mesh.ip(ref_res,ref_res)[1:end]
0
# Out:
# 0

# %%
plot(xtickfont=font(13), 
    ytickfont=font(11), 
    guidefont=font(17), 
    legendfont=font(13),legend = :right)

plot!(t,local_error,linewidth = 2,label = "L-POD")
plot!(t,overlap_error,linewidth = 2,label = "LO-POD")
plot!(t,global_error,linewidth = 2,label = "G-POD")
plot!(t,FD_error,linewidth = 2,label = "FD: " * L"128 \times 128")
vline!([12],color = "black",linewidth = 2,label = false)
ylabel!(L"||" *"Solution error"* L"||_2/||\mathbf{c}||_2")

xlabel!(L"t")
savefig("plots_2D/error.pdf")
plot!()

# %%
plot(xtickfont=font(13), 
    ytickfont=font(11), 
    guidefont=font(17), 
    legendfont=font(13),legend = :right)

plot!(t,local_energy,linewidth = 2,label = "L-POD")
plot!(t,overlap_energy,linewidth = 2,label = "LO-POD")
plot!(t,global_energy,linewidth = 2,label = "G-POD")
plot!(t,FD_energy,linewidth = 2,label = "FD: " * L"128 \times 128")
plot!(t,ref_energy,linewidth = 2,label = "DNS",color = "black")
vline!([12],color = "black",linewidth = 2,label = false)
ylabel!(L"E_r")
xlabel!(L"t")
savefig("plots_2D/energy.pdf")
plot!()

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title = "L-POD",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],local_res[:,:,1,end])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/L-POD.pdf", fig)
fig

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title = "LO-POD",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],overlap_res[:,:,1,end])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/LO-POD.pdf", fig)
fig

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title = "G-POD",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],global_res[:,:,1,end])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/G-POD.pdf", fig)
fig

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title =  L"\text{FD: }128 \times 128",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],FD_res[:,:,1,end])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/FD_128_128.pdf", fig)
fig

# %%
fig = cm.Figure(size = (650, 600))
ax = cm.Axis(fig[1, 1],title = "DNS",titlesize = 40,xticklabelsize = 20,yticklabelsize = 20)
hm = cm.heatmap!(fine_mesh.x[1:end,1,1,1],fine_mesh.x[1:end,1,1,1],ref_res[:,:,1,end])
#cm.title!(L"u = v = \cos(x-y)")
cm.Colorbar(fig[1, 2], hm,ticklabelsize = 20)
cm.save("plots_2D/DNS.pdf", fig)
fig
